# %%
import pandas as pd
from agents.evaluator.logging_util import set_verbose, verbose
from agents.evaluator.data import store
from agents.evaluator.engine.runner import run_backtest
from agents.evaluator.logging_util import set_verbose
from agents.evaluator.strategy.range_strategy import RangeBreakoutStrategy

set_verbose(True)        # global on
set_verbose(False)       # global off
# or scope to one run:
#with verbose():
#    run_backtest(df, strat, ticker="AAPL")
