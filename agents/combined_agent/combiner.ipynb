# %%
from combined import analyze_multiple_stocks
import pandas as pd


fundamental_cols = ["ticker","longName","ROCE (3yr avg)","NFAT (3yr avg)","SSGR",
"Av NPM (over 3 years)","Av NFA/T (over 3 years)",
"Av Dep%NFA (over 3 years)","Av Retention ratio (over 3 years)",
"Interest coverage","tax %","cCFO/cPAT","p/a",
"p/e","EY","Earnings Growth 5yr cagr","Sales Growth 5yr cagr",
"PEG","p/s","d/e","d/e_market","FCF%","FCF/CFO",
"3-5yr Average ROA (%)","3-5yr Average ROE (%)"
]

technical_cols = ['moving_averages.current_price', 'moving_averages.SMA_20', 'moving_averages.SMA_50', 'moving_averages.SMA_200',
 'moving_averages.above_50', 'moving_averages.above_200', 'moving_averages.golden_cross', 'moving_averages.dist_from_20',
 'moving_averages.dist_from_50', 'moving_averages.dist_from_200', 'moving_averages.score', 'moving_averages.max_score',
 'moving_averages.signal', 'macd.MACD', 'macd.MACD_signal', 'macd.MACD_hist', 'macd.bullish_crossover',
 'macd.above_zero', 'macd.histogram_positive', 'macd.histogram_growing', 'macd.recent_crossover',
 'macd.crossover_days_ago', 'macd.score', 'macd.max_score', 'macd.signal', 'rsi.RSI', 'rsi.not_overbought',
 'rsi.above_50', 'rsi.in_sweet_spot', 'rsi.zone', 'rsi.score', 'rsi.max_score', 'rsi.signal',
 'vwma.current_price', 'vwma.VWMA', 'vwma.above_vwma', 'vwma.vwma_rising',
 'vwma.volume_pattern_bullish', 'vwma.current_volume', 'vwma.avg_volume', 'vwma.volume_ratio',
 'vwma.avg_volume_up_days', 'vwma.avg_volume_down_days', 'vwma.score', 'vwma.max_score', 'vwma.signal']

# %%
a3 = pd.read_csv('../../raw_tickers/RAHUL_RECOS.txt', header = None)
list_stocks =[x.split()[0].split(':')[1] for x in a3.loc[0].values]
results = await analyze_multiple_stocks(list_stocks, batch_size=50)

df = pd.json_normalize(results.values())
df.to_csv('combined_csv/combined_analysis_rahul_recos.csv')

# %%
list_stocks = ['AMD','NVDA','GOOG','ANET','TPR','DECK','MU','WMT','TJX','EWBC','FER','ANF','APP','CALM','META','MSFT','LULU','CVS']
results = await analyze_multiple_stocks(list_stocks, batch_size=50)

df = pd.json_normalize(results.values())
df = df.round(3)
df[fundamental_cols+technical_cols].to_csv('combined_csv/consolidate1.csv')

df.to_csv('detailed_csv/consolidate1.csv')
# Out:
# Processing batch 1: ['AMD', 'NVDA', 'GOOG', 'ANET', 'TPR', 'DECK', 'MU', 'WMT', 'TJX', 'EWBC', 'FER', 'ANF', 'APP', 'CALM', 'META', 'MSFT', 'LULU', 'CVS']
# Completed batch 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 8
#       5 df = df.round(3)
#       6 df[fundamental_cols+technical_cols].to_csv('combined_csv/consolidate1.csv')
# ----> 8 df.to_csv('detailed_csv/consolidate1.csv')
#
# File ~/Documents/personal/financial_analysis/venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...

# %%
df.to_csv('detailed_csv/consolidate1.csv')

# %%
# !mkdir detailed_csv

# %%
import sys
import os
import pandas as pd
from datetime import datetime

# Add the parent directory (agents folder) to the path
current_dir = os.path.dirname(os.path.abspath('__file__'))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

from fundamental_analysis_agent.fundamental_analysis import FundamentalAnalysis
from technical_analysis_agent.technical_analysis import TechnicalAnalysis

# %%
fun = await f_an.compute_yfinance_metrics(stock)

# %%
income = stock.financials.transpose()# Transpose to rows=years, columns=items; recent first
balance = stock.balance_sheet.transpose()
cashflow = stock.cashflow.transpose()
info = stock.info# Dict for quote/profile/metrics

# %%
cashflow
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import asyncio
f_an = FundamentalAnalysis()
t_an = TechnicalAnalysis()

df, stock = await t_an.get_stock_data('DIG')

fun = await f_an.compute_yfinance_metrics(stock)
tech = await t_an.complete_technical_analysis(df)

# Run both functions in parallel
fun, tech = await asyncio.gather(
f_an.compute_yfinance_metrics(stock),
t_an.complete_technical_analysis(df)
, return_exceptions=True
)

complete_ = {**fun, **tech}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      10 # Run both functions in parallel
#      11 fun, tech = await asyncio.gather(
#      12     f_an.compute_yfinance_metrics(stock),
#      13     t_an.complete_technical_analysis(df)
#      14     , return_exceptions=True
#      15 )
# ---> 17 complete_ = {**fun, **tech}
#
# TypeError: 'str' object is not a mapping

# %%
complete_
# Out:
# {'ticker': 'AAPL',
#  'longName': 'Apple Inc.',
#  'ROCE': np.float64(65.33607652660827),
#  'ROCE (3yr avg)': np.float64(60.18927524652738),
#  'NFAT': np.float64(8.748475865540579),
#  'NFAT (3yr avg)': np.float64(8.761725054571576),
#  'NPM': np.float64(24.862376913154623),
#  'DPR': np.float64(15.537603549986954),
#  'Retention Ratio': np.float64(84.46239645001305),
#  'Dep': np.float64(26.2703050219738),
#  'SSGR': np.float64(157.72030797118032),
#  'Av NPM (over 3 years)': np.float64(24.862376913154623),
#  'Au NFA/T (over 3 years)': np.float64(8.761725054571576),
#  'Av Dep%NFA (over 3 years)': np.float64(26.2703050219738),
#  'Au Retention ratio (over 3 years)': np.float64(84.46239645001305),
#  'd/e': np.float64(1.7157821903260064),
#  'Interest coverage': np.float64(nan),
#  'tax %': np.float64(24.091185164189984),
#  'cPAT': np.float64(385214000000.0),
#  'CFO': np.float64(118254000000.0),
#  'cCFO': np.float64(454986000000.0),
# ...

# %%
pd.json_normalize(complete_)['macd.MACD']
# Out:
# 0    6.298416
# Name: macd.MACD, dtype: float64

# %%
complete_ = {**fun, **tech}

# %%
complete_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 complete_
#
# NameError: name 'complete_' is not defined

# %%
list_stocks
# Out:
# ['LAC',
#  'SCCO',
#  'RIOT',
#  'LBRT',
#  'OILU',
#  'FSLR',
#  'BITF',
#  'EQT',
#  'CPER',
#  'SMMT',
#  'INTC',
#  'BBAR',
#  'DIG',
#  'LCID',
#  'WMB',
#  'VIX',
#  'PWR',
#  'CRCL',
#  'TSLA',
#  'SG',
#  'CLSK',
#  'CELH',
#  'ENPH',
#  'TTE',
#  'MRVL',
#  'EVGO',
#  'TRGP',
#  'RGTI',
#  'YPF',
#  'MSTR',
#  'MARA',
#  'OXY',
#  'CEG',
#  'POWL',
#  'LULU',
#  'NEE',
#  'UCO',
#  'GNRC',
#  'ET',
#  'BITO',
#  'LNG',
#  'ANF',
#  'PCYO',
#  'UEC',
#  'BRENT',
#  'DKS',
#  'CLF',
#  'ETSY',
#  'AVAV',
#  'RTX',
#  'VKTX',
#  'COIN',
#  'IT',
#  'BHF',
#  'PYPL',
#  'NOW',
#  'TOL',
#  'ETN',
#  'UVXY',
#  'POR',
#  'PPTA',
#  'UNH',
#  'VTRS',
#  'UHS',
#  'KBH',
#  'GRBK',
#  'SRE',
#  'STGW',
#  'BNTX',
#  'RBLX',
#  'QBTS',
#  'U',
#  'PGR',
#  'HCA',
#  'THC',
#  'NUE',
#  'TJX',
#  'SRPT',
#  'TNX',
#  'CME',
#  'VXX',
#  'REGN',
#  'CROX',
#  'CBRL',
#  'PVH',
#  'COST',
#  'UA',
#  'LHX',
#  'ETHA',
#  'STLD',
#  'XRT',
#  'WULF',
#  'NRG',
#  'DUOL',
#  'ASH',
# ...

# %%
from combined import analyze_multiple_stocks
results = await analyze_multiple_stocks(list_stocks, batch_size=50)

df = pd.json_normalize(results.values())
df.to_csv('combined_csv/combined_analysis_rahul_recos.csv')

# %%
# Out:
# Processing batch 1: ['LAC', 'SCCO', 'RIOT', 'LBRT', 'OILU', 'FSLR', 'BITF', 'EQT', 'CPER', 'SMMT', 'INTC', 'BBAR', 'DIG', 'LCID', 'WMB', 'VIX', 'PWR', 'CRCL', 'TSLA', 'SG', 'CLSK', 'CELH', 'ENPH', 'TTE', 'MRVL', 'EVGO', 'TRGP', 'RGTI', 'YPF', 'MSTR', 'MARA', 'OXY', 'CEG', 'POWL', 'LULU', 'NEE', 'UCO', 'GNRC', 'ET', 'BITO', 'LNG', 'ANF', 'PCYO', 'UEC', 'BRENT', 'DKS', 'CLF', 'ETSY', 'AVAV', 'RTX']
# $VIX: possibly delisted; no price data found  (period=1y)
# No data found for VIX
# Error analyzing VIX: cannot unpack non-iterable NoneType object
# HTTP Error 404:
# $BRENT: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# No data found for BRENT
# Error analyzing BRENT: cannot unpack non-iterable NoneType object
# /Users/dhruvsabharwal/Documents/personal/financial_analysis/venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
# ...

# %%
from combined import analyze_multiple_stocks

# Usage
#tickers = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'TSLA', 'META', 'NVDA', 'NFLX', 'AMD', 'INTC']
# Add 90 more tickers as needed...
list_stocks = ['AMD','NVDA','GOOG','ANET','TPR','DECK','MU','WMT','TJX','EWBC','FER','ANF','INSM','SAN','SHG','GLD','APP','CALM','META','MSFT','LULU']
results = await analyze_multiple_stocks(list_stocks, batch_size=50)

df = pd.json_normalize(results.values())
df.to_csv('combined_csv/consolidate1.csv')
# Out:
# Processing batch 1: ['AMD', 'NVDA', 'GOOG', 'ANET', 'TPR', 'DECK', 'MU', 'WMT', 'TJX', 'EWBC', 'FER', 'ANF', 'INSM', 'SAN', 'SHG', 'GLD', 'APP', 'CALM', 'META', 'MSFT', 'LULU']
# Error analyzing GLD: 'str' object is not a mapping
# Completed batch 1

# %%
[df.columns]
# Out:
# Index(['ticker', 'longName', 'ROCE', 'ROCE (3yr avg)', 'NFAT',
#        'NFAT (3yr avg)', 'NPM', 'DPR', 'Retention Ratio', 'Dep',
#        ...
#        'market_context.score', 'market_context.total_checks',
#        'market_context.market_state', 'market_context.recommendation',
#        'relative_strength.stock_return_%',
#        'relative_strength.benchmark_return_%',
#        'relative_strength.outperformance_%', 'relative_strength.outperforming',
#        'relative_strength.signal', 'error'],
#       dtype='object', length=185)

# %%
list(df.columns)
# Out:
# ['ticker',
#  'longName',
#  'ROCE',
#  'ROCE (3yr avg)',
#  'NFAT',
#  'NFAT (3yr avg)',
#  'NPM',
#  'DPR',
#  'Retention Ratio',
#  'Dep',
#  'SSGR',
#  'Av NPM (over 3 years)',
#  'Au NFA/T (over 3 years)',
#  'Av Dep%NFA (over 3 years)',
#  'Au Retention ratio (over 3 years)',
#  'd/e',
#  'Interest coverage',
#  'tax %',
#  'cPAT',
#  'CFO',
#  'cCFO',
#  'cCFO/cPAT',
#  'p/a',
#  'p/e',
#  'EY',
#  'Earnings Growth 5yr cagr',
#  'Sales Growth 5yr cagr',
#  'PEG',
#  'no. shares (cr)',
#  'Current Price',
#  'market cap',
#  'd/e_market',
#  'p/s',
#  'NFA + CWIP',
#  'Capex',
#  'Capex_from_cashflow_statement',
#  'FCF',
#  'FCF%',
#  'FCF_capex_from_cashflow',
#  'FCF%_capex_from_cashflow',
#  'DV',
#  'Mcap (cr)',
#  'd/e decreasing trend 5 yrs',
#  'Sales cagr >15%',
#  'npm >8%',
#  'Tax payout >25%',
#  'Interest coverage >3',
#  'd/e <0.5',
#  'CFO >0',
#  'cCFO > PAT',
#  'p/e <10',
#  'peg <1',
#  'EY >7%',
#  'p/b <3',
#  'DV >3%',
#  'EY >7',
# ...

# %%
#df_results = pd.DataFrame.from_dict(results, orient='index')
df = pd.json_normalize(results.values())
df_results.to_csv('combined_csv/combined_analysis_rahul_recos.csv')

# %%
df_results = pd.read_csv('combined_csv/combined_analysis_rahul_recos.csv')

# %%
df_results[df_results['ticker']=='EWBC']
# Out:
#      Unnamed: 0 ticker                 longName  ROCE  ROCE (3yr avg)  \
# 151         151   EWBC  East West Bancorp, Inc.   NaN             0.0
#
#           NFAT  NFAT (3yr avg)        NPM        DPR  Retention Ratio  ...  \
# 151  14.896046       13.521759  46.446499  23.451774        76.548226  ...
#
#                  relative_strength.signal  error  Research Asset  \
# 151  AVOID - Significant underperformance    NaN             NaN
#
#      R&D Amortization  Adjusted EBIT (R&D)  Adjusted Book Equity (R&D)  \
# 151               NaN                  NaN                         NaN
#
#      Adjusted D/E (R&D)  Adjusted Invested Capital (R&D)  Adjusted ROC (R&D)  \
# 151                 NaN                              NaN                 NaN
#
#      Adjusted ROE (R&D)
# 151                 NaN
#
# [1 rows x 186 columns]

# %%
from google import genai

# Initialize with your API Key
client = genai.Client(api_key="AIzaSyChorYx5kolIvsSueVHX4GiigjoDFVNYWA")

# Send a prompt to the model
response = client.models.generate_content(
model="gemini-2.0-flash",
contents="Explain how APIs work to a 5 year old."
)

# Print the result
print(response.text)
# Out:
# Okay, imagine you want an ice cream cone.
#
# *   **You** (that's like you, the app on your tablet or phone) want an ice cream.
# *   **The Ice Cream Shop** (that's like a website or a server where the ice cream is stored) has all the different ice creams.
# *   **The API** (that's like the person behind the counter at the ice cream shop!) takes your order and gives you the ice cream you asked for.
#
# You say "I want a chocolate ice cream cone!" to the API person. The API person goes to the freezer, gets the chocolate ice cream, puts it in a cone, and hands it to you. You don't have to go behind the counter and find the ice cream yourself. The API person does all the work for you!
#
# So, the API helps your app get information or do things on another computer without you needing to know all the complicated stuff. It's like a friendly helper who gets what you need.

# %%
import yfinance as yf
stock = yf.Ticker('TPR')
income = stock.financials.transpose()# Transpose to rows=years, columns=items; recent first
balance = stock.balance_sheet.transpose()
cashflow = stock.cashflow.transpose()

income = income.reset_index().rename(columns={'index': 'Date'})
balance = balance.reset_index().rename(columns={'index': 'Date'})
cashflow = cashflow.reset_index().rename(columns={'index': 'Date'})


income['Date'] = pd.to_datetime(income['Date'])
balance['Date'] = pd.to_datetime(balance['Date'])
cashflow['Date'] = pd.to_datetime(cashflow['Date'])

income = income.sort_values('Date')
balance = balance.sort_values('Date')
cashflow = cashflow.sort_values('Date')

# %%
latest = -1

# Available years
num_years = len(income)
metrics = {}
ebit = income.get('EBIT', pd.Series([0]*num_years))
capital_employed = balance.get('Total Assets', pd.Series([0]*num_years)) - balance.get('Current Liabilities', pd.Series([0]*num_years))
metrics['ROCE'] = (ebit.iloc[latest] / capital_employed.iloc[latest] * 100) if capital_employed.iloc[latest] != 0 else 0
roce_3yr = [(ebit.iloc[i] / capital_employed.iloc[i] * 100) for i in range(-min(3, num_years), 0) if capital_employed.iloc[i] != 0]

# %%
net_income = income.get('Net Income', pd.Series([0]*num_years))
equity = balance.get('Stockholders Equity', pd.Series([0]*num_years)).shift(1)

# %%
net_income
# Out:
# 3    856300000.0
# 2    936000000.0
# 1    816000000.0
# 0    183200000.0
# Name: Net Income, dtype: float64
